# %% [markdown]
# ## Sorting and tagging customers

# %% [markdown]
# ## Sorting

# %%
def my_sort(xs,f=lambda x:x):
    n = len(xs)
    for i in range(n - 1):
        for j in range(0, n-i-1):
            if f(xs[j]) < f(xs[j+1]):
                xs[j],xs[j+1] =xs[j+1],xs[j]
                
    return xs

# %%
xs = [1000,20000.35,3.6,40.6,50,6000,70]
my_sort(xs)
# Out:
# [20000.35, 6000, 1000, 70, 50, 40.6, 3.6]

# %%
def my_sort_dict(xs, f = lambda x:x[1]):
    xs = [(k,v) for k,v in xs.items()]
    return {k: v for (k,v) in my_sort(xs,f)}

# %%
test_dict = {"customer1":9000, "customer2":5000}
test_dict
# Out:
# {'customer1': 9000, 'customer2': 5000}

# %%
test_dict.items()
# Out:
# dict_items([('customer1', 9000), ('customer2', 5000)])

# %%
my_sort_dict(test_dict)
# Out:
# {'customer1': 9000, 'customer2': 5000}

# %% [markdown]
# ## Applying to our dataset

# %%
import pandas as pd
import sqlite3

# %%
conn = sqlite3.connect("churn.db")

# %%
LTV= pd.read_sql("select CustomerID,TotalCharges from churn_all",conn)

# %%
LTV.TotalCharges
# Out:
# 0        108.15
# 1        151.65
# 2         820.5
# 3       3046.05
# 4        5036.3
#          ...
# 7038     1419.4
# 7039     1990.5
# 7040     7362.9
# 7041     346.45
# 7042     6844.5
# Name: TotalCharges, Length: 7043, dtype: object

# %%
LTV["TotalCharges"] = pd.to_numeric(LTV["TotalCharges"],errors="coerce")

# %%
LTV
# Out:
#       CustomerID  TotalCharges
# 0     3668-QPYBK        108.15
# 1     9237-HQITU        151.65
# 2     9305-CDSKC        820.50
# 3     7892-POOKP       3046.05
# 4     0280-XJGEX       5036.30
# ...          ...           ...
# 7038  2569-WGERO       1419.40
# 7039  6840-RESVB       1990.50
# 7040  2234-XADUH       7362.90
# 7041  4801-JZAZL        346.45
# 7042  3186-AJIEK       6844.50
#
# [7043 rows x 2 columns]

# %%
LTV = LTV.set_index("CustomerID").T.to_dict("records")[0]

# %%
LTV
# Out:
# {'3668-QPYBK': 108.15,
#  '9237-HQITU': 151.65,
#  '9305-CDSKC': 820.5,
#  '7892-POOKP': 3046.05,
#  '0280-XJGEX': 5036.3,
#  '4190-MFLUW': 528.35,
#  '8779-QRDMV': 39.65,
#  '1066-JKSGK': 20.15,
#  '6467-CHFZW': 4749.15,
#  '8665-UTDHZ': 30.2,
#  '8773-HHUOZ': 1093.1,
#  '6047-YHPVI': 316.9,
#  '5380-WJKOV': 3549.25,
#  '8168-UQWWF': 1105.4,
#  '7760-OYPDY': 144.15,
#  '9420-LOJKX': 1426.4,
#  '7495-OOKFY': 633.3,
#  '1658-BYGOY': 1752.55,
#  '5698-BQJOH': 857.25,
#  '5919-TMRGD': 79.35,
#  '9191-MYQKX': 496.9,
#  '8637-XJIVR': 927.35,
#  '0278-YXOOG': 113.85,
#  '4598-XLKNJ': 2514.5,
#  '3192-NQECA': 7611.85,
#  '0486-HECZI': 5238.9,
#  '4846-WHAFZ': 2868.15,
#  '5299-RULOA': 1064.65,
#  '0404-SWRVG': 229.55,
#  '4412-YLTKF': 2135.5,
#  '6207-WIOLX': 1502.65,
#  '3091-FYHKI': 35.45,
#  '2372-HWUHI': 81.25,
#  '0390-DCFDQ': 70.45,
#  '4080-OGPJL': 563.65,
#  '2135-RXIHG': 45.65,
#  '3874-EQOEP': 655.5,
#  '0867-MKZVY': 1592.35,
#  '3376-BMGFE': 273.0,
#  '3445-HXXGF': 2651.2,
#  '1875-QIVME': 242.8,
#  '0691-JVSYA': 5000.2,
#  '2656-FMOKZ': 1145.7,
#  '2070-FNEXE': 503.6,
#  '6317-YPKDH': 29.95,
#  '9367-WXLCH': 662.65,
#  '1918-ZBFQJ': 1111.65,
#  '1024-GUALD': 24.8,
#  '2472-OVKUP': 531.0,
#  '1285-OKIPP': 79.9,
#  '7825-ECJRF': 1934.45,
#  '7841-TZDMQ': 84.5,
#  '9408-SSNVZ': 268.35,
#  '0742-MOABM': 179.35,
#  '2232-DMLXU': 55.2,
#  '8937-RDTHP': 84.6,
#  '1251-KRREG': 114.1,
#  '0094-OIFMO': 1120.3,
#  '9947-OTFQU': 1074.3,
#  '0322-YINQP': 48.55,
#  '4629-NRXKX': 147.15,
#  '9514-JDSKI': 40.2,
#  '4959-JOSRX': 80.55,
#  '7273-TEFQD': 132.2,
#  '3606-TWKGI': 1364.3,
#  '6323-AYBRX': 1099.6,
#  '4385-GZQXV': 1511.2,
#  '6366-ZGQGL': 24.8,
#  '5940-AHUHD': 70.6,
#  '6432-TWQLB': 401.1,
#  '4484-GLZOU': 5624.85,
#  '9512-UIBFX': 1779.95,
#  '5583-SXDAG': 70.0,
#  '3488-PGMQJ': 606.55,
#  '3580-REOAC': 435.4,
#  '7534-BFESC': 1712.7,
#  '6390-DSAZX': 73.6,
#  '8098-LLAZX': 396.1,
#  '0265-EDXBD': 2303.35,
#  '7563-BIUPC': 415.55,
#  '2321-OMBXY': 3058.65,
#  '2840-XANRC': 2231.05,
#  '5020-ZSTTY': 4350.1,
#  '5804-LEPIM': 139.05,
#  '0122-OAHPZ': 511.25,
#  '2868-SNELZ': 155.8,
#  '4322-RCYMT': 5293.95,
#  '6680-NENYN': 4759.85,
#  '1343-EHPYB': 6603.0,
#  '2034-GDRCN': 168.2,
#  '0219-YTZUE': 371.9,
#  '0623-IIHUG': 840.1,
#  '4572-DVCGN': 846.0,
#  '9057-MSWCO': 805.1,
#  '1010-DIAUQ': 492.55,
#  '0259-GBZSH': 181.5,
#  '9601-BRXPO': 2566.5,
#  '6905-NIQIN': 50.65,
#  '5167-ZFFMM': 90.85,
#  '4895-TMWIR': 214.75,
#  '0533-BNWKF': 4874.7,
#  '6599-CEBNN': 2524.45,
#  '0979-PHULV': 7007.6,
#  '4800-VHZKI': 19.9,
#  '7989-CHGTL': 19.6,
#  '0334-GDDSO': 233.7,
#  '0578-SKVMF': 1845.9,
#  '5564-NEMQO': 75.3,
#  '9063-ZGTUY': 1182.55,
#  '2957-LOLHO': 518.9,
#  '7752-XUSCI': 6396.45,
#  '4110-PFEUZ': 69.55,
#  '0256-LTHVJ': 2227.1,
#  '0880-TKATG': 385.9,
#  '3811-VBYBZ': 673.25,
#  '4640-UHDOS': 734.35,
#  '3583-EKAPL': 55.0,
#  '9399-APLBT': 74.7,
#  '2359-KMGLI': 1861.5,
#  '0306-JAELE': 453.4,
#  '6227-HWPWX': 994.8,
#  '0447-BEMNG': 2145.0,
#  '5949-XIKAE': 680.05,
#  '8372-JUXUI': 74.35,
#  '0388-EOPEX': 139.4,
#  '8205-OTCHB': 903.6,
#  '6235-VDHOM': 131.05,
#  '7783-YKGDV': 1238.45,
#  '5609-CEBID': 1782.4,
#  '7218-HKQFK': 167.5,
#  '4636-QRJKY': 502.85,
#  '5956-VKDTT': 334.8,
#  '9412-GHEEC': 4131.95,
#  '0257-ZESQC': 1929.35,
#  '6825-UYPFK': 1758.6,
#  '8397-MVTAZ': 3480.0,
#  '9282-IZGQK': 85.0,
#  '1342-JPNKI': 834.1,
#  '2817-NTQDO': 597.0,
#  '6986-IJDHX': 3266.0,
#  '5301-GAUUY': 2596.15,
#  '0939-YAPAF': 3527.6,
#  '4710-FDUIZ': 5614.45,
#  '1218-VKFPE': 233.55,
#  '3627-FHKBK': 75.3,
#  '2865-TCHJW': 346.2,
#  '5192-EBGOV': 85.7,
#  '0719-SYFRB': 713.75,
#  '3419-SNJJD': 6786.4,
#  '6543-CPZMK': 248.95,
#  '4765-OXPPD': 663.05,
#  '1009-IRMNA': 137.6,
#  '4554-YGZIH': 4547.25,
#  '5099-BAILX': 4687.9,
#  '7207-RMRDB': 6985.65,
#  '4913-EHYUI': 5794.65,
#  '0195-IESCP': 855.3,
#  '4580-TMHJU': 2499.3,
#  '0970-ETWGE': 89.55,
#  '1626-ERCMM': 1899.65,
#  '0887-HJGAR': 45.7,
#  '5644-PDMZC': 161.5,
#  '9576-ANLXO': 222.3,
#  '2024-BASKD': 74.6,
#  '4160-AMJTL': 164.3,
#  '4464-JCOLN': 35.9,
#  '5650-VDUDS': 96.05,
#  '7538-GWHML': 145.15,
#  '3859-CVCET': 191.05,
#  '3276-HDUEG': 75.05,
#  '0823-HSCDJ': 2550.9,
#  '0822-GAVAP': 62.25,
#  '1448-PWKYE': 80.0,
#  '0067-DKWBL': 91.1,
#  '2276-YDAVZ': 270.7,
#  '5896-NPFWW': 168.15,
#  '7133-VBDCG': 2015.35,
#  '1029-QFBEN': 19.55,
#  '4952-YSOGZ': 381.3,
#  '1589-AGTLK': 141.5,
#  '5244-IRFIH': 3105.55,
#  '2684-EIWEO': 2758.15,
#  '6439-GTPCA': 3941.7,
#  '5138-WVKYJ': 1008.55,
#  '6683-VLCTZ': 1842.8,
#  '2189-WWOEW': 1269.55,
#  '1894-IGFSG': 1907.85,
#  '7379-POKDZ': 208.85,
#  '0236-HFWSV': 1444.65,
#  '3900-AQPHZ': 19.9,
#  '5842-POCOP': 454.15,
#  '2037-XJFUP': 3036.75,
#  '7314-OXENN': 184.65,
#  '0322-CHQRU': 89.5,
#  '4678-DVQEO': 52.2,
#  '0691-IFBQW': 4874.8,
#  '3009-JWMPU': 6125.4,
#  '1450-GALXR': 1058.25,
#  '3138-BKYAV': 489.45,
#  '4289-DTDKW': 4113.1,
#  '1820-TQVEV': 69.55,
#  '2239-JALAW': 6017.65,
#  '4853-RULSV': 7250.15,
#  '6275-YDUVO': 178.7,
#  '0115-TFERT': 2317.1,
#  '2311-QYMUQ': 1430.25,
#  '3643-AHCFP': 644.35,
#  '3104-OWCGK': 5453.4,
#  '9101-BWFSS': 5610.7,
#  '9231-ZJYAM': 292.8,
#  '6982-SSHFK': 44.4,
#  '0727-BMPLR': 5509.3,
#  '1038-ZAGBI': 229.6,
#  '3027-ZTDHO': 89.9,
#  '2382-BCKQJ': 6413.65,
#  '2207-NHRJK': 50.8,
#  '0947-MUGVO': 1463.5,
#  '9944-HKVVB': 307.4,
#  '4124-MMETB': 2104.55,
#  '3671-SHRSP': 319.15,
#  '3313-QKNKB': 5084.65,
#  '5073-WXOYN': 3027.4,
#  '0207-MDKNV': 1582.75,
#  '9851-KIELU': 1043.3,
#  '3908-BLSYF': 497.55,
#  '7549-MYGPK': 6215.35,
#  '3804-RVTGV': 5017.9,
#  '9227-LUNBG': 24.6,
#  '4315-MURBD': 1120.95,
#  '9734-YWGEX': 923.5,
#  '2719-BDAQO': 1625.65,
#  '0781-LKXBR': 918.6,
#  '1907-UBQFC': 688.65,
#  '6513-EECDB': 73.55,
#  '7074-IEVOJ': 205.05,
#  '9625-QSTYE': 952.3,
#  '4750-ZRXIU': 360.1,
#  '6400-BWQKW': 434.5,
#  '6680-WKXRZ': 215.8,
#  '7028-DVOIQ': 3395.8,
#  '4208-UFFGW': 85.15,
#  '9448-REEVD': 44.7,
#  '9117-SHLZX': 45.7,
#  '9889-TMAHG': 832.35,
#  '4541-RMRLG': 112.3,
#  '3158-MOERK': 174.8,
#  '7294-TMAOP': 90.55,
#  '8919-FYFQZ': 1359.7,
#  '2834-JRTUA': 7532.15,
#  '5875-YPQFJ': 69.9,
#  '6646-QVXLR': 6383.35,
#  '8603-IJWDN': 86.6,
#  '9369-XFEHK': 2656.5,
#  '3842-IYKUE': 2917.5,
#  '6641-XRPSU': 2416.1,
#  '1374-DMZUI': 424.45,
#  '8357-EQXFO': 660.9,
#  '1989-PRJHP': 1893.95,
#  '9524-EGPJC': 1612.75,
#  '6993-OHLXR': 119.75,
#  '8818-XYFCQ': 3204.65,
#  '4695-VADHF': 990.85,
#  '3863-IUBJR': 696.35,
#  '4822-RVYBB': 819.4,
#  '8436-BJUMM': 2070.6,
#  '4184-TJFAN': 273.75,
#  '4145-UQXUQ': 729.95,
#  '9948-YPTDG': 3013.05,
#  '1236-WFCDV': 1266.1,
#  '4883-QICIH': 2347.9,
#  '8329-IBCTI': 19.65,
#  '1271-SJBGZ': 526.95,
#  '5669-SRAIP': 210.75,
#  '5981-ITEMU': 3706.95,
#  '6941-PMGEP': 412.5,
#  '1624-WOIWJ': 832.05,
#  '2074-GKOWZ': 185.55,
#  '0376-YMCJC': 1943.2,
#  '0634-SZPQA': 2169.8,
#  '5536-RTPWK': 4853.75,
#  '6166-ILMNY': 144.55,
#  '3097-NNSPB': 91.1,
#  '0655-RBDUG': 713.0,
#  '4361-BKAXE': 4527.45,
#  '9878-TNQGW': 171.15,
#  '4441-NIHPT': 940.35,
#  '8999-BOHSE': 1047.7,
#  '7029-RPUAV': 1622.45,
#  '4607-CHPCA': 2178.6,
#  '8824-RWFXJ': 168.15,
#  '9763-PDTKK': 387.2,
#  '7627-JKIAZ': 2839.65,
#  '4081-DYXAV': 893.55,
#  '8111-SLLHI': 4284.8,
#  '0927-LCSMG': 544.55,
#  '8257-RZAHR': 941.0,
#  '5293-WXJAK': 1133.65,
#  '0841-NULXI': 35.55,
#  '7851-WZEKY': 196.9,
#  '8844-TONUD': 1162.85,
#  '4086-YQSNZ': 224.05,
#  '5868-CZJDR': 31.35,
#  '0135-NMXAP': 1052.4,
#  '6270-OMFIW': 5610.25,
#  '0107-WESLM': 19.85,
#  '3992-YWPKO': 669.45,
#  '0125-LZQXK': 1553.95,
#  '8399-YNDCH': 1236.15,
#  '5673-FSSMF': 60.15,
#  '1579-KLYDT': 593.45,
#  '3927-NLNRY': 4867.95,
#  '6358-LYNGM': 74.9,
#  '5494-HECPR': 80.25,
#  '9824-BEMCV': 1149.65,
#  '1373-ORVIZ': 740.8,
#  '9866-QEVEE': 1532.45,
#  '9897-KXHCM': 250.05,
#  '7979-CORPM': 2282.55,
#  '1618-CFHME': 143.35,
#  '3165-HDOEW': 45.85,
#  '6581-NQCBA': 810.2,
#  '1689-MRZQR': 2564.3,
#  '5835-BEQEU': 228.4,
#  '5565-FILXA': 1529.2,
#  '5552-ZNFSJ': 45.3,
#  '2223-KAGMX': 289.3,
#  '7321-PKUYW': 987.95,
#  '2833-SLKDQ': 45.05,
#  '7595-EUIVN': 75.8,
#  '2026-TGDHM': 523.15,
#  '4030-VPZBD': 59.05,
#  '4187-CINZD': 4424.2,
#  '6818-WOBHJ': 6127.6,
#  '2408-TZMJL': 6448.05,
#  '9134-CEQMF': 676.7,
#  '7993-PYKOF': 632.95,
#  '5027-XWQHA': 270.95,
#  '4566-QVRRW': 483.7,
#  '8519-IMDHU': 1345.55,
#  '0201-OAMXR': 8127.6,
#  '3372-KWFBM': 1281.0,
#  '7831-QGOXH': 1553.9,
#  '6393-WRYZE': 3207.55,
#  '6599-RCLCJ': 5124.55,
#  '9831-BPFRI': 3474.45,
#  '1725-MIMXW': 19.45,
#  '0031-PVLZI': 76.35,
#  '7206-GZCDC': 69.25,
#  '4791-QRGMF': 5961.1,
#  '1768-ZAIFU': 25.2,
#  '4671-LXRDQ': 96.45,
#  '1934-SJVJK': 20.15,
#  '3838-OZURD': 7133.25,
#  '9269-CQOOL': 169.45,
#  '2845-HSJCY': 1258.6,
#  '1184-PJVDB': 857.2,
#  '9415-DPEWS': 1639.3,
#  '7943-RQCHR': 889.9,
#  '3793-MMFUH': 1290.0,
#  '3249-ZPQRG': 330.05,
#  '2568-BRGYX': 237.95,
#  '7721-JXEAW': 2452.7,
#  '7249-WBIYX': 813.85,
#  '6567-HOOPW': 79.2,
#  '3164-AALRN': 347.4,
#  '3334-CTHOL': 49.95,
#  '4704-ERYFC': 1554.0,
#  '8621-MNIHH': 3217.55,
#  '0471-LVHGK': 3001.2,
#  '9518-RWHZL': 6254.2,
#  '5419-CONWX': 442.85,
#  '6240-EURKS': 553.0,
#  '6960-HVYXR': 76.0,
#  '7024-OHCCK': 170.85,
#  '7861-UVUFT': 1308.4,
#  '5357-TZHPP': 732.5,
#  '0680-DFNNY': 1504.05,
#  '7767-UXAGJ': 50.45,
#  '1571-SAVHK': 1132.75,
#  '9546-CQJSU': 193.6,
#  '0506-LVNGN': 349.65,
#  '2951-QOQTK': 332.45,
#  '3473-XIIIT': 1534.75,
#  '7893-IXHRQ': 20.55,
#  '2952-QAYZF': 424.15,
#  '4763-PGDPO': 281.0,
#  '5394-SVGJV': 3475.55,
#  '9283-LZQOH': 896.75,
#  '7079-QRCBC': 2407.3,
#  '5469-CTCWN': 6547.7,
#  '9851-QXEEQ': 4346.4,
#  '9809-IMGCQ': 2082.95,
#  '5208-HFSBT': 102.75,
#  '3254-YRILK': 1775.8,
#  '2667-WYLWJ': 145.0,
#  '0529-ONKER': 1146.65,
#  '5240-IJOQT': 74.7,
#  '1092-GANHU': 1313.55,
#  '0661-XEYAN': 25.8,
#  '7881-EVUAD': 72.4,
#  '5766-XQXMQ': 1970.5,
#  '3703-VAVCL': 190.05,
#  '8519-QJGJD': 1025.95,
#  '6326-MTTXK': 819.55,
#  '0330-IVZHA': 330.15,
#  '2886-KEFUM': 6873.75,
#  '4237-RLAQD': 45.85,
#  '9651-GTSAQ': 5769.75,
#  '3186-BAXNB': 91.7,
#  '0637-YLETY': 1555.65,
#  '1157-BQCUW': 74.95,
#  '2660-EMUBI': 898.35,
#  '7675-OZCZG': 127.1,
#  '2003-CKLOR': 6710.5,
#  '9254-RBFON': 1704.95,
#  '1205-WNWPJ': 415.95,
#  '9391-EOYLI': 950.2,
#  '8387-MOJJT': 3384.0,
#  '2761-OCIAX': 165.4,
#  '3068-OMWZA': 88.8,
#  '6032-KRXXO': 2755.35,
#  '7459-RRWQZ': 994.55,
#  '4154-AQUGT': 1169.35,
#  '3092-IGHWF': 5918.8,
#  '8017-LXHFA': 2293.6,
#  '6352-TWCAU': 3029.1,
#  '2929-QNSRW': 5508.35,
#  '1262-OPMFY': 655.9,
#  '4248-QPAVC': 1463.45,
#  '1899-VXWXM': 5082.8,
#  '4690-LLKUA': 770.6,
#  '3331-HQDTW': 3587.25,
#  '9490-DFPMD': 3541.35,
#  '5442-XSDCW': 868.5,
#  '3049-NDXFL': 85.8,
#  '8580-AECUZ': 79.1,
#  '7963-GQRMY': 134.5,
#  '1228-FZFRV': 5341.8,
#  '2058-DCJBE': 324.6,
#  '5364-XYIRR': 4812.75,
#  '4829-AUOAX': 4399.5,
#  '5047-LHVLY': 50.15,
#  '9158-VCTQB': 4594.95,
#  '6311-UEUME': 2384.15,
#  '6839-ITVZJ': 1616.15,
#  '0375-HVGXO': 34.7,
#  '8593-WHYHV': 264.8,
#  '6097-EQISJ': 6615.15,
#  '4423-YLHDV': 2200.25,
#  '0107-YHINA': 99.75,
#  '8640-SDGKB': 299.7,
#  '4116-TZAQJ': 639.65,
#  '3877-JRJIP': 59.85,
#  '8375-DKEBR': 69.6,
#  '7511-YMXVQ': 418.8,
#  '7551-JOHTI': 19.5,
#  '9804-ICWBG': 69.9,
#  '5318-IXUZF': 183.75,
#  '3198-VELRD': 264.85,
#  '9436-ZBZCT': 1178.4,
#  '7279-BUYWN': 4689.5,
#  '7156-MHUGY': 1201.15,
#  '7198-GLXTC': 143.65,
#  '0516-VRYBW': 390.85,
#  '8380-PEFPE': 71.65,
#  '5687-DKDTV': 77.5,
#  '7530-HDYDS': 3264.5,
#  '3096-IZETN': 947.3,
#  '5922-ABDVO': 1761.05,
#  '9172-ANCRX': 973.25,
#  '6910-HADCM': 76.35,
#  '4816-LXZYW': 1676.95,
#  '9606-PBKBQ': 2642.05,
#  '3536-IQCTX': 2661.1,
#  '4911-BANWH': 2697.4,
#  '8496-EJAUI': 1424.5,
#  '3132-TVFDZ': 2572.95,
#  '8080-DDEMJ': 45.1,
#  '6365-MTGZX': 2122.45,
#  '1349-WXNGG': 20.05,
#  '6990-YNRIO': 6937.95,
#  '0621-TWIEM': 402.6,
#  '2485-ITVKB': 68.75,
#  '3669-OYSJI': 46.2,
#  '1612-EOHDH': 45.15,
#  '6702-OHFWR': 43.3,
#  '4510-PYUSH': 2250.65,
#  '7517-SAWMO': 1441.1,
#  '4143-HHPMK': 4338.6,
#  '7054-LGEQW': 45.95,
#  '0923-PNFUB': 247.25,
#  '3494-JCHRQ': 70.05,
#  '6474-FVJLC': 165.45,
#  '8840-DQLGN': 3653.35,
#  '4547-LYTDD': 1194.3,
#  '6770-XUAGN': 21.0,
#  '4193-ORFCL': 45.1,
#  '7776-QWNFX': 1527.5,
#  '6689-TCZHQ': 378.4,
#  '3143-ILDAL': 5124.6,
#  '4720-VSTSI': 3862.55,
#  '3946-MHCZW': 50.9,
#  '6651-AZVTJ': 4872.45,
#  '4566-GOLUK': 5118.95,
#  '2484-DGXPZ': 658.95,
#  '4587-NUKOX': 246.5,
#  '0420-BWTPW': 215.2,
#  '8183-ONMXC': 159.45,
#  '9614-RMGHA': 5940.85,
#  '5054-IEXZT': 75.35,
#  '5834-ASPWA': 75.45,
#  '3948-XHGNA': 1210.4,
#  '0565-IYCGT': 5356.45,
#  '5445-UTODQ': 576.65,
#  '1024-VRZHF': 825.7,
#  '9497-QCMMS': 93.55,
#  '0348-SDKOL': 5885.4,
#  '4373-MAVJG': 1259.0,
#  '8901-HJXTF': 309.1,
#  '5419-KLXBN': 2257.75,
#  '3424-NMNBO': 6287.25,
#  '4514-GFCFI': 1350.15,
#  '9828-AOQLM': 45.7,
#  '8000-REIQB': 69.95,
#  '7615-ESMYF': 97.1,
#  '3858-VOBET': 1710.45,
#  '1447-PJGGA': 5464.65,
#  '8565-CLBZW': 2165.05,
#  '9139-WQQDY': 4941.8,
#  '0224-HJAPT': 223.15,
#  '8086-OVPWV': 181.1,
#  '9430-FRQOC': 341.45,
#  '3074-GQWYX': 357.75,
#  '6845-RGTYS': 4533.7,
#  '8861-HGGKB': 830.85,
#  '7065-YUNRY': 45.3,
#  '7694-VLBWQ': 7040.85,
#  '4795-KTRTH': 371.65,
#  '6481-OGDOO': 6056.15,
#  '3753-TSEMP': 1390.6,
#  '8305-VHZBZ': 20.2,
#  '9172-JITSM': 2361.8,
#  '6298-QDFNH': 1730.35,
#  '9961-JBNMK': 2030.3,
#  '6173-ITPWD': 4065.0,
#  '9734-UYXQI': 106.55,
#  '2189-UXTKY': 1742.75,
#  '4958-GZWIY': 340.25,
#  '6356-ELRKD': 95.6,
#  '8624-GIOUT': 2934.3,
#  '6179-GJPSO': 4600.7,
#  '3177-LASXD': 71.35,
#  '4897-QSUYC': 20.15,
#  '1084-UQCHV': 69.75,
#  '8290-YWKHZ': 2931.0,
#  '2955-BJZHG': 1400.85,
#  '3806-DXQOM': 137.85,
#  '9300-RENDD': 79.95,
#  '0761-AETCS': 19.3,
#  '2153-MREFK': 3754.6,
#  '3106-ULWFW': 627.4,
#  '0925-VYDLG': 242.0,
#  '4349-GFQHK': 54.35,
#  '7802-EFKNY': 100.4,
#  '8035-BUYVG': 1716.45,
#  '9787-XVQIU': 75.3,
#  '8945-MUQUF': 4837.6,
#  '8051-HJRLT': 70.55,
#  '3023-GFLBR': 2745.7,
#  '0524-IAVZO': 2624.25,
#  '2737-YNGYW': 184.1,
#  '5159-YFPKQ': 160.75,
#  '4021-RQSNY': 3004.15,
#  '9061-TIHDA': 1233.65,
#  '8699-ASUFO': 527.9,
#  '7927-AUXBZ': 2555.9,
#  '4695-WJZUE': 179.25,
#  '7619-ODSGN': 1338.15,
#  '3988-RQIXO': 91.3,
#  '2514-GINMM': 79.5,
#  '5931-FLJJF': 467.55,
#  '2659-VXMWZ': 7482.1,
#  '3207-OYBWH': 5427.05,
#  '4285-GYRQC': 587.1,
#  '7216-EWTRS': 100.8,
#  '8337-MSSXB': 1180.95,
#  '8182-BJDSI': 2625.55,
#  '2528-HFYZX': 1233.4,
#  '2482-CZGBB': 740.0,
#  '0866-QLSIR': 2088.75,
#  '7181-BQYBV': 102.45,
#  '6204-IEUXJ': 217.55,
#  '4529-CKBCL': 146.05,
#  '2506-CLAKW': 567.45,
#  '1583-IHQZE': 1384.75,
#  '0151-ONTOV': 70.9,
#  '4140-MUHUG': 220.95,
#  '0320-JDNQG': 2331.3,
#  '7180-PISOG': 74.5,
#  '3571-RFHAR': 6941.2,
#  '9578-VRMNM': 1043.35,
#  '1587-FKLZB': 6822.15,
#  '6140-QNRQQ': 71.55,
#  '4307-KTUMW': 5029.2,
#  '5440-FLBQG': 7318.2,
#  '7470-MCQTK': 633.4,
#  '7488-MXJIV': 321.65,
#  '2027-FECZV': 1253.9,
#  '2672-DZUOY': 25.15,
#  '3870-MQAMG': 5893.15,
#  '4800-CZMPC': 5037.55,
#  '7377-DMMRI': 92.45,
#  '8949-JTMAY': 2933.2,
#  '2774-LVQUS': 1258.3,
#  '3211-ILJTT': 1214.05,
#  '4612-THJBS': 5510.65,
#  '4094-NSEDU': 1973.75,
#  '5103-MHMHY': 45.95,
#  '1846-XWOQN': 70.15,
#  '0235-KGSLC': 85.55,
#  '2884-GBPFB': 2416.55,
#  '3757-NJYBX': 3520.75,
#  '5136-KCKGI': 3467.0,
#  '3722-WPXTK': 88.35,
#  '2929-ERCFZ': 777.3,
#  '7548-SEPYI': 512.45,
#  '8835-VSDSE': 141.45,
#  '1623-NLDOT': 1445.3,
#  '9898-KZQDZ': 3640.45,
#  '5236-PERKL': 6465.0,
#  '7854-FOKSF': 35.9,
#  '2519-FAKOD': 3777.15,
#  '8263-JQAIK': 47.5,
#  '7089-IVVAZ': 847.3,
#  '2205-YMZZJ': 546.95,
#  '1254-IZEYF': 3186.65,
#  '9492-TOKRI': 1527.35,
#  '9221-OTIVJ': 1531.4,
#  '3325-FUYCG': 2847.4,
#  '5908-QMGOE': 1133.9,
#  '8481-YYXWG': 461.7,
#  '2609-IAICY': 77.15,
#  '1740-CSDJP': 35.25,
#  '2636-OHFMN': 201.0,
#  '1323-OOEPC': 5149.5,
#  '0397-GZBBC': 5574.75,
#  '7641-EUYET': 4541.2,
#  '9921-ZVRHG': 1072.0,
#  '4701-MLJPN': 1715.65,
#  '9206-GVPEQ': 706.85,
#  '1596-BBVTG': 2636.05,
#  '8433-WXGNA': 189.2,
#  '3707-GNWHM': 74.25,
#  '8922-LIEGH': 2187.55,
#  '8245-UMPYT': 1581.2,
#  '5186-SAMNZ': 69.5,
#  '5373-SFODM': 3132.75,
#  '5766-ZJYBB': 19.4,
#  '8931-GJJIQ': 803.3,
#  '4277-PVRAN': 679.3,
#  '0022-TCJCI': 2791.5,
#  '0203-HHYIJ': 676.35,
#  '0952-KMEEH': 1230.25,
#  '8178-EYZUO': 4154.8,
#  '5130-IEKQT': 2655.25,
#  '3230-WYKIR': 1425.45,
#  '0407-BDJKB': 5742.9,
#  '9600-UDOPK': 2866.45,
#  '4074-SJFFA': 54.75,
#  '3269-ATYWD': 3759.05,
#  '4910-GMJOT': 94.6,
#  '0354-WYROK': 2911.3,
#  '7576-OYWBN': 231.8,
#  '5539-TMZLF': 69.75,
#  '4323-SADQS': 279.25,
#  '4446-BZKHU': 6281.45,
#  '5202-IVJNU': 1131.3,
#  '5976-JCJRH': 738.2,
#  '0137-OCGAB': 80.2,
#  '3351-NQLDI': 6341.45,
#  '7593-JNWRU': 260.8,
#  '4588-YBNIB': 19.6,
#  '3336-JORSO': 3655.45,
#  '5028-GZLDO': 140.7,
#  '6861-XWTWQ': 665.45,
#  '6877-TJMBR': 84.8,
#  '6769-DCQLI': 5426.85,
#  '2433-KMEAS': 1127.35,
#  '2195-ZRVAX': 4045.65,
#  '3550-SAHFP': 2757.85,
#  '2011-TRQYE': 600.0,
#  '4873-ILOLJ': 2238.5,
#  '2725-KXXWT': 90.75,
#  '9565-DJPIB': 365.65,
#  '8348-HFYIV': 90.35,
#  '6849-WLEYG': 19.75,
#  '4659-NZRUF': 1789.25,
#  '8429-XIBUM': 2317.1,
#  '2608-BHKFN': 266.9,
#  '7341-LXCAF': 301.4,
#  '9462-MJUAW': 206.6,
#  '8128-YVJRG': 604.7,
#  '4283-FUTGF': 1471.75,
#  '1569-TTNYJ': 412.1,
#  '2397-BRLOM': 583.45,
#  '4749-VFKVB': 50.1,
#  '7598-UAASY': 151.8,
#  '7938-OUHIO': 293.65,
#  '8510-AWCXC': 1308.1,
#  '0431-APWVY': 2598.95,
#  '3426-NIYYL': 765.5,
#  '8225-BTJAU': 793.55,
#  '3387-VATUS': 462.8,
#  '1143-NMNQJ': 169.8,
#  '0415-MOSGF': 44.4,
#  '1724-BQUHA': 477.7,
#  '4826-XTSOH': 86.05,
#  '2495-INZWQ': 174.3,
#  '4139-SUGLD': 1077.5,
#  '6857-VWJDT': 95.65,
#  '5624-BQSSA': 20.95,
#  '2408-WITXK': 329.8,
#  '5577-OTWWW': 297.3,
#  '6100-QQHEB': 1515.1,
#  '2634-HCZGT': 3229.65,
#  '7503-QQRVF': 1178.25,
#  '2691-NZETQ': 758.6,
#  '4404-HIBDJ': 1863.8,
#  '7295-JOMMD': 396.3,
#  '5013-SBUIH': 5551.15,
#  '0709-TVGUR': 622.9,
#  '6023-YEBUP': 329.95,
#  '7209-JCUDS': 1048.85,
#  '3001-CBHLQ': 3351.55,
#  '6158-DWPZT': 259.8,
#  '3763-GCZHZ': 6890.0,
#  '0772-GYEQQ': 262.05,
#  '4831-EOBFE': 2649.15,
#  '4102-OQUPX': 74.4,
#  '9170-GYZJC': 3326.2,
#  '3999-QGRJH': 560.85,
#  '2454-RPBRZ': 1060.2,
#  '2002-MZHWP': 20.5,
#  '2265-CYWIV': 347.65,
#  '2004-OCQXK': 81.95,
#  '5027-QPKTE': 451.1,
#  '2672-HUYVI': 455.3,
#  '7508-MYBOG': 1235.55,
#  '0148-DCDOS': 2362.1,
#  '9992-RRAMN': 1873.7,
#  '0310-MVLET': 6010.05,
#  '4550-VBOFE': 7101.5,
#  '5696-QURRL': 45.05,
#  '7409-KIUTL': 71.0,
#  '1732-VHUBQ': 3309.25,
#  '0495-RVCBF': 79.7,
#  '7854-EDSSA': 1254.7,
#  '8869-TORSS': 2896.4,
#  '0679-IDSTG': 69.25,
#  '2115-BFTIW': 1767.35,
#  '0611-DFXKO': 1820.45,
#  '7780-OTDSO': 1742.95,
#  '9747-DDZOS': 73.5,
#  '0564-JJHGS': 829.1,
#  '3348-CFRNX': 2602.9,
#  '1428-GTBJJ': 824.75,
#  '8802-UNOJF': 1029.75,
#  '6313-GIDIT': 2854.55,
#  '2845-AFFTX': 4259.3,
#  '2249-YPRNG': 2239.65,
#  '7410-YTJIK': 480.75,
#  '4626-GYCZP': 635.6,
#  '5590-BYNII': 2095.0,
#  '3237-AJGEH': 95.05,
#  '1591-NFNLQ': 4242.35,
#  '2815-CPTUL': 331.9,
#  '0596-BQCEQ': 6283.3,
#  '1481-ZUWZA': 2659.4,
#  '2309-OSFEU': 298.45,
#  '1891-FZYSA': 6143.15,
#  '7613-LLQFO': 1059.55,
#  '2640-PMGFL': 2180.55,
#  '3801-HMYNL': 89.15,
#  '9685-WKZGT': 1036.75,
#  '6022-UGGSO': 2276.95,
#  '4484-CGXFK': 196.15,
#  '6214-EDAKZ': 1206.05,
#  '6127-ISGTU': 1378.25,
#  '8740-XLHDR': 219.0,
#  '1208-DNHLN': 1067.15,
#  '1761-AEZZR': 79.55,
#  '3923-CSIHK': 3444.85,
#  '7120-RFMVS': 84.5,
#  '7317-GGVPB': 7690.9,
#  '1322-AGOQM': 1380.1,
#  '3677-IYRBF': 78.65,
#  '5692-FPTAH': 45.4,
#  '1550-LOAHA': 2585.95,
#  '0268-QKIWO': 58.85,
#  '0876-WDUUZ': 425.9,
#  '0617-FHSGK': 3678.3,
#  '2858-MOFSQ': 937.5,
#  '8118-LSUEL': 2483.5,
#  '7005-CCBKV': 556.35,
#  '4250-FDVOU': 389.1,
#  '5277-ZLOOR': 187.45,
#  '2141-RRYGO': 261.25,
#  '6376-GAHQE': 299.2,
#  '5052-PNLOS': 323.25,
#  '6979-ZNSFF': 762.1,
#  '2386-LAHRK': 53.5,
#  '6032-IGALN': 25.1,
#  '4248-HCETZ': 2365.15,
#  '0516-WJVXC': 308.25,
#  '9174-FKWZE': 19.45,
#  '8809-RIHDD': 7372.65,
#  '4822-NGOCH': 1058.6,
#  '5307-DZCVC': 2628.6,
#  '8679-JOEVF': 1023.9,
#  '1432-FPAXX': 856.35,
#  '4803-AXVYP': 3734.25,
#  '3884-HCSWG': 1144.5,
#  '5077-DXTCG': 45.3,
#  '1142-WACZW': 75.6,
#  '5649-ANRML': 180.25,
#  '4892-VLANZ': 19.8,
#  '2919-HBCJO': 333.6,
#  '4236-XPXAV': 465.05,
#  '3030-YZADT': 431.0,
#  '7410-KTVFV': 878.35,
#  '8393-DLHGA': 2448.75,
#  '7395-IGJOS': 1329.2,
#  '2834-SPCJV': 4348.65,
#  '7890-VYYWG': 93.7,
#  '9907-SWKKF': 25.05,
#  '0587-DMGBH': 365.55,
#  '6397-JNZZG': 2342.2,
#  '3523-QRQLL': 1498.2,
#  '0895-DQHEW': 5278.15,
#  '8149-RSOUN': 93.85,
#  '7250-EQKIY': 50.45,
#  '4013-UBXWQ': 521.1,
#  '5519-NPHVG': 1046.1,
#  '8849-GYOKR': 5763.3,
#  '3148-BLQJT': 20.1,
#  '0461-CVKMU': 1900.25,
#  '8806-EAGWC': 159.15,
#  '7779-LGOVN': 856.65,
#  '9710-ZUSHQ': 4056.75,
#  '4183-WCSEP': 2435.15,
#  '5498-TXHLF': 2874.15,
#  '9722-UJOJR': 1974.8,
#  '3902-FOIGH': 1218.55,
#  '6772-KSATR': 81.7,
#  '7112-OPOTK': 2171.15,
#  '4210-QFJMF': 317.25,
#  '3318-OSATS': 3474.05,
#  '5828-AVIPD': 1875.55,
#  '1086-LXKFY': 69.1,
#  '2636-ALXXZ': 69.6,
#  '7774-OJSXI': 3066.45,
#  '7786-WBJYI': 305.55,
#  '9885-CSMWE': 78.45,
#  '5016-ETTFF': 255.25,
#  '3866-MDTUB': 146.9,
#  '8058-JMEQO': 762.5,
#  '0697-ZMSWS': 338.9,
#  '7657-DYEPJ': 2497.35,
#  '8276-MQBYC': 4913.3,
#  '7593-XFKDI': 46.3,
#  '0337-CNPZE': 4443.45,
#  '1513-XNPPH': 1095.65,
#  '6015-VVHHE': 446.05,
#  '6347-DCUIK': 811.8,
#  '0897-FEGMU': 1056.95,
#  '7663-RGWBC': 44.15,
#  '1120-BMWUB': 834.15,
#  '9124-LHCJQ': 85.45,
#  '2235-ZGKPT': 239.55,
#  '3891-PUQOD': 59.2,
#  '0689-NKYLF': 1060.6,
#  '3658-KIBGF': 54.9,
#  '5519-YLDGW': 2254.2,
#  '4946-EDSEW': 180.3,
#  '2516-VQRRV': 158.4,
#  '7580-UGXNC': 104.2,
#  '5178-LMXOP': 95.1,
#  '8185-UPYBR': 438.0,
#  '4585-HETAI': 325.45,
#  '7526-BEZQB': 1148.1,
#  '4951-UKAAQ': 355.2,
#  '2108-YKQTY': 151.3,
#  '4918-QLLIW': 188.7,
#  '7056-IMHCC': 5549.4,
#  '1625-JAIIY': 5685.8,
#  '2947-DOMLJ': 50.6,
#  '4112-LUEIZ': 863.1,
#  '4510-HIMLV': 69.8,
#  '8749-JMNKX': 4750.95,
#  '2430-USGXP': 2391.8,
#  '5955-ERIHD': 1687.95,
#  '0917-EZOLA': 7689.95,
#  '5949-EBSQK': 229.55,
#  '7274-RTAPZ': 90.55,
#  '0311-UNPFF': 2274.35,
#  '3834-XUIFC': 602.55,
#  '8414-MYSHR': 449.75,
#  '7599-FKVXZ': 4512.7,
#  '8229-TNIQA': 196.95,
#  '6221-AVQYL': 131.05,
#  '7743-EXURX': 415.05,
#  '5569-KGJHX': 754.65,
#  '4988-IQIGL': 75.35,
#  '7730-IUTDZ': 3198.6,
#  '0426-TIRNE': 20.9,
#  '7587-RZNME': 123.65,
#  '0748-RDGGM': 7534.65,
#  '4706-AXVKM': 906.85,
#  '5889-JTMUL': 4888.7,
#  '9026-RNUJS': 237.25,
#  '3746-EUBYR': 74.6,
#  '2332-EFBJY': 342.4,
#  '9474-PHLYD': 892.65,
#  '2165-VOEGB': 4822.85,
#  '2219-MVUSO': 438.4,
#  '8914-RBTSB': 3019.5,
#  '0963-ZBDRN': 3183.4,
#  '7594-RQHXR': 79.6,
#  '6331-EWIEB': 1734.5,
#  '5998-VVEJY': 2088.8,
#  '1624-NALOJ': 502.6,
#  '4317-VTEOA': 50.75,
#  '1670-SVOWZ': 1208.35,
#  '7541-YLXCL': 2498.4,
#  '0260-ZDLGK': 651.4,
#  '8722-NGNBH': 223.45,
#  '6210-KBBPI': 919.4,
#  '0133-BMFZO': 181.65,
#  '6128-CZOMY': 45.65,
#  '9540-JYROE': 551.35,
#  '2260-USTRB': 115.95,
#  '3656-TKRVZ': 165.2,
#  '8623-TMRBY': 4146.05,
#  '1501-SGHBW': 81.0,
#  '3208-YPIOE': 3017.65,
#  '2612-RANWT': 1164.3,
#  '6900-PXRMS': 2710.25,
#  '3346-BRMIS': 810.7,
#  '2933-FILNV': 36.55,
#  '9986-BONCE': 85.5,
#  '2722-JMONI': 49.55,
#  '4083-EUGRJ': 178.5,
#  '7579-OOPEC': 115.1,
#  '1771-OADNZ': 2745.2,
#  '0612-RTZZA': 25.25,
#  '6410-LEFEN': 416.45,
#  '3194-ORPIK': 4116.15,
#  '8816-VXNZD': 75.1,
#  '9378-FXTIZ': 3715.65,
#  '1723-HKXJQ': 4273.45,
#  '7825-GKXMW': 45.8,
#  '1240-KNSEZ': 20.1,
#  '0836-SEYLU': 328.95,
#  '4433-JCGCG': 4680.05,
#  '3716-BDVDB': 69.1,
#  '5899-MQZZL': 999.45,
#  '6849-OYAMU': 1888.65,
#  '9488-HGMJH': 71.15,
#  '6038-GCYEC': 1240.25,
#  '1150-WFARN': 7156.2,
#  '3144-AUDBS': 270.8,
#  '5616-PRTNT': 374.5,
#  '4818-QIUFN': 1520.9,
#  '6961-VCPMC': 3605.2,
#  '6688-UZPWD': 1145.35,
#  '2839-RFSQE': 38.7,
#  '0968-GSIKN': 70.8,
#  '1965-DDBWU': 1448.6,
#  '9057-SIHCH': 291.9,
#  '6771-XWBDM': 5921.35,
#  '8601-QACRS': 249.95,
#  '2391-SOORI': 219.65,
#  '2645-QTLMB': 669.0,
#  '4806-HIPDW': 68.95,
#  '4424-TKOPW': 196.75,
#  '8443-ZRDBZ': 318.9,
#  '9136-ALYBR': 24.45,
#  '7479-NITWS': 631.85,
#  '2959-MJHIC': 307.4,
#  '4201-JMNGR': 55.8,
#  '5960-WPXQM': 79.05,
#  '0684-AOSIH': 95.0,
#  '8260-NGFNY': 25.2,
#  '1866-RZZQS': 4187.75,
#  '8631-NBHFZ': 5154.6,
#  '4958-XCBDQ': 3496.3,
#  '8337-UPOAQ': 914.3,
#  '1725-IQNIY': 6110.2,
#  '6598-RFFVI': 28.3,
#  '6712-OAWRH': 2351.8,
#  ...}

# %%
my_sort_dict(LTV)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 my_sort_dict(LTV)
#
# NameError: name 'my_sort_dict' is not defined

# %% [markdown]
# ## Tagging customers

# %%
def create_seg(df,LTV_col,target_col,LTV_value,upper_seg = "High",lower_seg ="Low"):
    df[target_col]= df[LTV_col].map(lambda x:upper_seg if x > LTV_value else lower_seg)
    return df

# %%
df = pd.read_sql("select * from churn_all",conn)

# %%
df["TotalCharges"] = pd.to_numeric(df["TotalCharges"], errors="coerce")

# %%
LTV_value = df.TotalCharges.quantile(0.80)

# %%
churn_tagged = create_seg(df,"TotalCharges","LTV_segment",LTV_value)

# %%
churn_tagged.LTV_segment.value_counts()
# Out:
# Low     5636
# High    1407
# Name: LTV_segment, dtype: int64

# %% [markdown]
# ## Creating the LTV_analysis class

# %%
class LTV_analysis:
    
    def __init__(self):
        pass
    
    def my_sort(self,xs,f=lambda x:x):
        n = len(xs)
        for i in range(n - 1):
            for j in range(0, n-i-1):
                if f(xs[j]) < f(xs[j+1]):
                    xs[j],xs[j+1] =xs[j+1],xs[j]

        return xs 
   
    def my_sort_dict(self,xs, f = lambda x:x[1]):
        xs = [(k,v) for k,v in xs.items()]
        return {k: v for (k,v) in my_sort(xs,f)}
    
    def create_seg(self,df,LTV_col,target_col,LTV_value,upper_seg = "High",lower_seg ="Low"):
        self.df[target_col]= self.df[LTV_col].map(lambda x:upper_seg if x > LTV_value else lower_seg)
        return df

# %%
l = LTV_analysis()

# %%
l.my_sort_dict(LTV)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [26], in <cell line: 1>()
# ----> 1 l.my_sort_dict(LTV)
#
# Input In [24], in LTV_analysis.my_sort_dict(self, xs, f)
#      15 def my_sort_dict(self,xs, f = lambda x:x[1]):
#      16     xs = [(k,v) for k,v in xs.items()]
# ---> 17     return {k: v for (k,v) in my_sort(xs,f)}
#
# NameError: name 'my_sort' is not defined

# %%
#l.create_seg(df,"TotalCharges","LTV_segment",LTV_value)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [27], in <cell line: 1>()
# ----> 1 l.create_seg(df,"TotalCharges","LTV_segment",LTV_value)
#
# Input In [24], in LTV_analysis.create_seg(self, df, LTV_col, target_col, LTV_value, upper_seg, lower_seg)
#      19 def create_seg(self,df,LTV_col,target_col,LTV_value,upper_seg = "High",lower_seg ="Low"):
# ---> 20     self.df[target_col]= self.df[LTV_col].map(lambda x:upper_seg if x > LTV_value else lower_seg)
#      21     return df
#
# AttributeError: 'LTV_analysis' object has no attribute 'df'
